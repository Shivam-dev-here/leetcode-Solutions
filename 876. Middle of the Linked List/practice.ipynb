# %% [markdown]
# #### Print

# %%
class  Node:
    def __init__(self, data):
        self.data = data
        self.next = None

node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)

node1.next = node2
node2.next = node3
node3.next = node4

current = node1


while current is not None:
    print(current.data, end=" -> ")
    current = current.next
print("None")
# Out:
# 10 -> 20 -> 30 -> 40 -> None

# %% [markdown]
# #### Rear Insertion

# %%
class  Node:
    def __init__(self, data):
        self.data = data
        self.next = None

node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)

node1.next = node2
node2.next = node3
node3.next = node4

current = node1


while current.next is not None:
    current = current.next
    
new_node = Node(50)
current.next = new_node

# %% [markdown]
# #### Front Insertion

# %%
class  Node:
    def __init__(self, data):
        self.data = data
        self.next = None
node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)

node1.next = node2
node2.next = node3
node3.next = node4

head = node1
current = head

new_node = Node(00)
new_node.next = current
current = new_node

while current is not None:
    print(current.data, end=" -> ")
    current = current.next
print("None")
# Out:
# 0 -> 10 -> 20 -> 30 -> 40 -> None

# %% [markdown]
# #### Search a Node, Trial: A

# %%
class  Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def operation(self, data,arr):
        node1 = Node(10)
        node2 = Node(20)
        node3 = Node(30)
        node4 = Node(40)

        node1.next = node2
        node2.next = node3
        node3.next = node4

        head = node1
        current = head
        search_data = 30

        while current is not None:
            for i in arr:
                if(current.data == search_data):
                    arr.append("Found")
                else:
                    arr.append("Not Found")
            current = current.next
        return arr

    arr = [30,50]
    result = [operation(arr)]
    print("result")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 class  Node:
#       2     def __init__(self, data):
#       3         self.data = data
#
# Cell In[2], line 30, in Node()
#      27     return arr
#      29 arr = [30,50]
# ---> 30 result = [operation(arr)]
#      31 print("result")
#
# TypeError: Node.operation() missing 2 required positional arguments: 'data' and 'arr'

# %% [markdown]
# #### Search a Node, Trial: B

# %%
class  Node:
    def __init__(self, data):
        self.data = data
        self.next = None

node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)
node5 = Node(50)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

head = node1
current = head
count = 0

while current is not None:
    count +=1
    current = current.next

current = head
for i in range(int((count)/2)):
    current = current.next

print(current.data)
# Out:
# 30

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
    
node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)
node5 = Node(50)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = None

head = node1
current = head
slow = current
fast = current

while fast and fast.next is not None:
        slow = slow.next
        fast = fast.next.next

print(slow.data)
# Out:
# 30
